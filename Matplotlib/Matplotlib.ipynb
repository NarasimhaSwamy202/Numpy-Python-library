# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.arange(0,10,0.1)
y = 2*x+5

plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,10,1)
y = 2*x+5

fig = plt.figure(figsize=(10,10))
plt.plot(x,y, linewidth = 1, linestyle = '-', color = 'r', alpha = 0.9, marker = 'H')
plt.title("Line Plot Demo")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(['Line1'], loc = 'upper right')
plt.grid(True)

# %%
import matplotlib.pyplot as plt

x = [3, 1, 3]
y = [3, 2, 1]
plt.plot(x, y,color= "r")
plt.plot(y, x,color= "black")

plt.legend(["x,y", "y,x"])
plt.show()

# %%
x = np.arange(0,10,1)
y1 = 2*x+5
y2 = 3*x+10

plt.subplot(1,2,1)
plt.plot(x,y1, linewidth = '4')
plt.title('Graph1')

plt.subplot(1,2,2)
plt.plot(x,y2)
plt.title('Graph2')
# Out:
# Text(0.5, 1.0, 'Graph2')

# %%
data = {'apples':20,'mangoes':30,'lemon':25}
names = list(data.keys())
values = list(data.values())

plt.barh(names, values, color = 'orange')
plt.title('Bar chart')
plt.xlabel('Fruits count')
plt.ylabel('Fruits')
plt.legend(['Bars'], loc = 'best')

# %%
a = np.arange(10,60,10)
b = [5,3,2,6,1]
c = [1,2,3,4,6]

plt.scatter(a,b, c='g', s=200, marker = 's', alpha = 0.6)
plt.scatter(a,c, c = 'r', s =400, marker = 'H', alpha = 0.7)

plt.title('Scatterplot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend(['Scatter1', 'Scatter2'], loc = 'best')

# %%
numbers = [10,12,16,19,11,20,26,28,30,38,35,34,45,60,68,64,62,70,78,75,79,85,94,95]

plt.hist(numbers, bins = [0,20,40,60,80,100],edgecolor = 'black', color = 'r')
# Out:
# (array([5., 7., 1., 8., 3.]),
#  array([  0,  20,  40,  60,  80, 100]),
#  <BarContainer object of 5 artists>)

# %%
total = [20,4,1,30,20,10,20,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,20,10,5,10,20,50,60,20,25]

data = list([total,order,discount])

data
# Out:
# [[20, 4, 1, 30, 20, 10, 20, 70, 30, 10],
#  [10, 3, 1, 15, 17, 2, 30, 44, 2, 1],
#  [30, 20, 10, 5, 10, 20, 50, 60, 20, 25]]

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa8b1a275b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa8b1a27b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa8b1a272e0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fa8b1a35130>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa8b1a35400>,
# ...
#  'means': []}

# %%
plt.violinplot(data, showmeans= True, showmedians = True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7fa8d1fdbc10>,
# ...
#  'cmeans': <matplotlib.collections.LineCollection at 0x7fa8d1fdbb80>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7fa8a1706ac0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7fa8a1706ee0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7fa8a1702550>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7fa8a1702e50>}

# %%
x = ['Dogs', 'Cats' , 'Rats', 'Lions']
y = [40,25,10,55]
explode = [0,0,0,0.1]
plt.pie(y, labels = x,autopct = '%0.0f%%', shadow = True, explode = [0.9,0,0,0.1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa8b1b6c7f0>,
# ...
#  [Text(1.1361294341905337, 1.6459677726996658, 'Dogs'),
#   Text(-0.9052823042371465, 0.624871146425471, 'Cats'),
#   Text(-1.068035972151765, -0.26324734032813074, 'Rats'),
#   Text(0.28717894399343613, -1.1651301447163809, 'Lions')],
#  [Text(0.8520970756429003, 1.234475829524749, '31%'),
#   Text(-0.49379034776571623, 0.340838807141166, '19%'),
#   Text(-0.5825650757191444, -0.1435894583607986, '8%'),
#   Text(0.16752105066283773, -0.6796592510845555, '42%')])

# %%
y = [10,3,1,15,17,2,30,44,2,1]
x = np.arange(0,len(y),1)

plt.stackplot(x,y,colors='black', alpha = 0.3)
plt.plot(x,y, color ='g')
plt.grid(True)

# %%
y = [10,3,1,15,17,2,30,44,2,1]
x = np.arange(0,len(y),1)
plt.stackplot(x,y,colors='black', alpha = 0.3)
plt.plot(x,y, color = 'g')
plt.grid(True)

# %% [markdown]
# ## **3D plots**

# %%
import matplotlib.pyplot as plt
# Creating the figure object
fig = plt.figure()

ax = plt.axes(projection = '3d')

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [1, 8, 27, 64, 125]

fig = plt.figure()
# keeping the projection = 3d
# creates the 3d plot
ax = plt.axes(projection = '3d')
ax.plot3D(z, y, x)
